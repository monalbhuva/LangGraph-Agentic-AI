# %%
from langgraph.graph import StateGraph, START, END
from langchain_groq import ChatGroq
from dotenv import load_dotenv
from typing import TypedDict, Annotated
from pydantic import BaseModel,Field
import operator

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGroq(model='openai/gpt-oss-120b')

# %%
class EvalutionSchema(BaseModel):

    feedback : str = Field(description='Detailed feedback for the essay')
    score : float = Field(description='Score out of 10',ge=0,le=10)

# %%
structure_model = model.with_structured_output(EvalutionSchema)

# %%
essay = """India in the Age of AI
As the world enters a transformative era defined by artificial intelligence (AI), India stands at a critical juncture — one where it can either emerge as a global leader in AI innovation or risk falling behind in the technology race. The age of AI brings with it immense promise as well as unprecedented challenges, and how India navigates this landscape will shape its socio-economic and geopolitical future.

India's strengths in the AI domain are rooted in its vast pool of skilled engineers, a thriving IT industry, and a growing startup ecosystem. With over 5 million STEM graduates annually and a burgeoning base of AI researchers, India possesses the intellectual capital required to build cutting-edge AI systems. Institutions like IITs, IIITs, and IISc have begun fostering AI research, while private players such as TCS, Infosys, and Wipro are integrating AI into their global services. In 2020, the government launched the National AI Strategy (AI for All) with a focus on inclusive growth, aiming to leverage AI in healthcare, agriculture, education, and smart mobility.

One of the most promising applications of AI in India lies in agriculture, where predictive analytics can guide farmers on optimal sowing times, weather forecasts, and pest control. In healthcare, AI-powered diagnostics can help address India’s doctor-patient ratio crisis, particularly in rural areas. Educational platforms are increasingly using AI to personalize learning paths, while smart governance tools are helping improve public service delivery and fraud detection.

However, the path to AI-led growth is riddled with challenges. Chief among them is the digital divide. While metropolitan cities may embrace AI-driven solutions, rural India continues to struggle with basic internet access and digital literacy. The risk of job displacement due to automation also looms large, especially for low-skilled workers. Without effective skilling and re-skilling programs, AI could exacerbate existing socio-economic inequalities.

Another pressing concern is data privacy and ethics. As AI systems rely heavily on vast datasets, ensuring that personal data is used transparently and responsibly becomes vital. India is still shaping its data protection laws, and in the absence of a strong regulatory framework, AI systems may risk misuse or bias.

To harness AI responsibly, India must adopt a multi-stakeholder approach involving the government, academia, industry, and civil society. Policies should promote open datasets, encourage responsible innovation, and ensure ethical AI practices. There is also a need for international collaboration, particularly with countries leading in AI research, to gain strategic advantage and ensure interoperability in global systems.

India’s demographic dividend, when paired with responsible AI adoption, can unlock massive economic growth, improve governance, and uplift marginalized communities. But this vision will only materialize if AI is seen not merely as a tool for automation, but as an enabler of human-centered development.

In conclusion, India in the age of AI is a story in the making — one of opportunity, responsibility, and transformation. The decisions we make today will not just determine India’s AI trajectory, but also its future as an inclusive, equitable, and innovation-driven society."""

# %%
prompt = f'Evaluate the language quality of the following essay and provide a feedback and assign a score out of 10 \n {essay}'
structure_model.invoke(prompt).feedback
# Out:
# 'The essay presents a clear, well‑structured argument about India’s opportunities and challenges in the AI era. The introduction sets the context effectively, and each subsequent paragraph develops a distinct point—strengths, sectoral applications, challenges, and policy recommendations—culminating in a concise conclusion. The language is generally precise, with appropriate academic vocabulary (e.g., “transformative era,” “demographic dividend,” “human‑centered development”) and varied sentence structures that keep the reading engaging.\n\nStrengths:\n- Logical flow and coherent organization; headings are implicit but the progression is easy to follow.\n- Good use of specific data (5\u202fmillion STEM graduates, National AI Strategy 2020) that lends credibility.\n- Balanced treatment of opportunities and risks, showing critical thinking.\n- Effective rhetorical devices such as parallelism (“opportunity, responsibility, and transformation”).\n\nAreas for improvement:\n- A few minor grammatical slips (e.g., “the risk of job displacement … also looms large, especially for low‑skilled workers” could be smoother as “especially among low‑skilled workers”).\n- Some sentences are lengthy and could be split for readability (e.g., the sentence beginning with “To harness AI responsibly…”).\n- Repetition of the phrase “AI‑driven”/“AI‑powered” could be varied with synonyms.\n- The essay could benefit from a brief mention of concrete policy examples (e.g., data protection bill) to strengthen the recommendations.\n\nOverall, the essay demonstrates strong command of English, clear articulation of ideas, and a persuasive tone suitable for an academic or policy audience. Minor refinements would raise it to an exemplary level.'

# %%
structure_model.invoke(prompt).score
# Out:
# 8.5

# %%
class UPSCState(TypedDict):
    essay : str
    language_feedback : str
    analysis_feedback : str
    clarity_feedback : str
    overall_feedback : str
    individual_score : Annotated[list[int], operator.add]
    avg_score : float

# %%
def evaluate_language(state : UPSCState):

    prompt = f'Evaluate the language quality of the following essay and provide a feedback and assign a score out of 10 \n {state["essay"]}'

    output = structure_model.invoke(prompt)

    return {'language_feedback': output.feedback,'individual_score': [output.score] }

# %%
def evaluate_analysis(state : UPSCState):

    prompt = f'Evaluate the depth of analysis of the following essay and provide a feedback and assign a score out of 10 \n {state["essay"]}'

    output = structure_model.invoke(prompt)

    return {'analysis_feedback': output.feedback,'individual_score': [output.score] }

# %%
def evaluate_thought(state : UPSCState):

    prompt = f'Evaluate the clarityof the thought of the following essay and provide a feedback and assign a score out of 10 \n {state["essay"]}'

    output = structure_model.invoke(prompt)

    return {'clarity_feedback': output.feedback,'individual_score': [output.score] }

# %%
def final_evaluation(state : UPSCState):

    # summary feedback
    prompt = f'Based on the following feedbacks create a summarized feedback \n language feedback - {state["language_feedback"]} \n depth of analysis feedback - {state["analysis_feedback"]} \n clarity of thought feedback - {state["clarity_feedback"]}'
    overall_feedback = model.invoke(prompt).content

    # avg calculate
    avg_score = sum(state['individual_score'])/len(state['individual_score'])

    return {'overall_feedback': overall_feedback, 'avg_score': avg_score}

# %%
graph = StateGraph(UPSCState)

graph.add_node('evaluate_language',evaluate_language)
graph.add_node('evaluate_analysis',evaluate_analysis)
graph.add_node('evaluate_thought',evaluate_thought)
graph.add_node('final_evaluation',final_evaluation)

graph.add_edge(START,'evaluate_language')
graph.add_edge(START,'evaluate_analysis')
graph.add_edge(START,'evaluate_thought')

graph.add_edge('evaluate_language','final_evaluation')
graph.add_edge('evaluate_analysis','final_evaluation')
graph.add_edge('evaluate_thought','final_evaluation')

graph.add_edge('final_evaluation',END)

workflow = graph.compile()

workflow

# %%
intial_state = {
    'essay': essay
}

workflow.invoke(intial_state)
# Out:
# {'essay': "India in the Age of AI\nAs the world enters a transformative era defined by artificial intelligence (AI), India stands at a critical juncture — one where it can either emerge as a global leader in AI innovation or risk falling behind in the technology race. The age of AI brings with it immense promise as well as unprecedented challenges, and how India navigates this landscape will shape its socio-economic and geopolitical future.\n\nIndia's strengths in the AI domain are rooted in its vast pool of skilled engineers, a thriving IT industry, and a growing startup ecosystem. With over 5 million STEM graduates annually and a burgeoning base of AI researchers, India possesses the intellectual capital required to build cutting-edge AI systems. Institutions like IITs, IIITs, and IISc have begun fostering AI research, while private players such as TCS, Infosys, and Wipro are integrating AI into their global services. In 2020, the government launched the National AI Strategy (AI for All) with a focus on inclusive growth, aiming to leverage AI in healthcare, agriculture, education, and smart mobility.\n\nOne of the most promising applications of AI in India lies in agriculture, where predictive analytics can guide farmers on optimal sowing times, weather forecasts, and pest control. In healthcare, AI-powered diagnostics can help address India’s doctor-patient ratio crisis, particularly in rural areas. Educational platforms are increasingly using AI to personalize learning paths, while smart governance tools are helping improve public service delivery and fraud detection.\n\nHowever, the path to AI-led growth is riddled with challenges. Chief among them is the digital divide. While metropolitan cities may embrace AI-driven solutions, rural India continues to struggle with basic internet access and digital literacy. The risk of job displacement due to automation also looms large, especially for low-skilled workers. Without effective skilling and re-skilling programs, AI could exacerbate existing socio-economic inequalities.\n\nAnother pressing concern is data privacy and ethics. As AI systems rely heavily on vast datasets, ensuring that personal data is used transparently and responsibly becomes vital. India is still shaping its data protection laws, and in the absence of a strong regulatory framework, AI systems may risk misuse or bias.\n\nTo harness AI responsibly, India must adopt a multi-stakeholder approach involving the government, academia, industry, and civil society. Policies should promote open datasets, encourage responsible innovation, and ensure ethical AI practices. There is also a need for international collaboration, particularly with countries leading in AI research, to gain strategic advantage and ensure interoperability in global systems.\n\nIndia’s demographic dividend, when paired with responsible AI adoption, can unlock massive economic growth, improve governance, and uplift marginalized communities. But this vision will only materialize if AI is seen not merely as a tool for automation, but as an enabler of human-centered development.\n\nIn conclusion, India in the age of AI is a story in the making — one of opportunity, responsibility, and transformation. The decisions we make today will not just determine India’s AI trajectory, but also its future as an inclusive, equitable, and innovation-driven society.",
#  'language_feedback': 'The essay presents a clear and well‑structured overview of India’s position in the emerging AI era. It opens with a strong hook, follows a logical progression from strengths to applications, challenges, and policy recommendations, and ends with a concise conclusion that ties the arguments together. The language is generally fluent, with varied sentence structures and appropriate academic vocabulary (e.g., “transformative era,” “multi‑stakeholder approach,” “human‑centered development”).\n\nStrengths:\n- **Coherence and organization** – each paragraph focuses on a distinct theme, making the argument easy to follow.\n- **Use of data** – specific figures (5\u202fmillion STEM graduates) and concrete examples (agriculture, healthcare) lend credibility.\n- **Balanced perspective** – the essay acknowledges both opportunities and risks, showing critical insight.\n\nAreas for improvement:\n- **Minor grammatical slips** – a few articles are missing or misplaced (e.g., “the risk of job displacement … also looms large” could be “the risk of job displacement … also looms large”).\n- **Repetition** – the phrase “AI‑led growth” and “AI‑driven solutions” appear several times; varying wording would improve stylistic flow.\n- **Citation of sources** – while not essential for a short essay, referencing the National AI Strategy or recent policy documents would strengthen authority.\n- **Depth of analysis** – the discussion of ethical and regulatory issues could be expanded with specific policy proposals or examples of existing frameworks.\n\nOverall, the essay demonstrates strong command of English, logical argumentation, and persuasive rhetoric, with only minor language and stylistic issues that prevent it from being flawless.\n\n**Score: 8.5/10**',
#  'analysis_feedback': 'The essay provides a clear, well‑structured overview of India’s position in the emerging AI era. It identifies key strengths (large STEM talent pool, IT industry, startup ecosystem, government initiatives) and outlines several promising application domains (agriculture, healthcare, education, governance). The discussion of challenges – digital divide, job displacement, data privacy, and regulatory gaps – shows an awareness of the broader socio‑economic context. \n\nHowever, the depth of analysis is limited in several ways:\n1. **Evidence and specificity** – The essay cites broad numbers (e.g., "over 5\u202fmillion STEM graduates") but does not back claims with concrete data, case studies, or recent policy milestones that would strengthen the argument.\n2. **Critical evaluation** – While challenges are listed, the essay does not critically assess the effectiveness of existing measures (e.g., the National AI Strategy) or explore trade‑offs between rapid AI adoption and ethical safeguards.\n3. **Comparative perspective** – There is little comparison with how other emerging economies are handling similar AI challenges, which would contextualise India’s relative position.\n4. **Implementation pathways** – Recommendations such as "multi‑stakeholder approach" and "open datasets" remain high‑level; the essay could benefit from concrete policy proposals, funding mechanisms, or governance models.\n5. **Future scenarios** – The conclusion is aspirational but lacks scenario analysis (e.g., best‑case vs. worst‑case outcomes) that would demonstrate deeper strategic thinking.\n\nOverall, the essay is coherent and covers the major themes, but it stays at a descriptive level rather than delivering a deep, evidence‑based analysis. For a stronger piece, the author should integrate more data, critically evaluate current initiatives, and provide detailed, actionable recommendations.\n\n**Score (out of 10): 7** – The essay shows solid understanding and organization but falls short of a thorough, analytical depth expected at a higher academic or policy‑analysis level.',
#  'clarity_feedback': 'The essay presents a clear and well‑structured argument about India’s position in the AI era. It opens with a strong thesis, outlines India’s strengths (human capital, institutions, industry), highlights concrete application areas (agriculture, healthcare, education, governance), and then balances optimism with a thorough discussion of challenges (digital divide, job displacement, data privacy). The transition between sections is logical, and the concluding paragraph effectively reinforces the central message that AI must be harnessed responsibly for inclusive growth. Minor issues that slightly detract from clarity include a few long sentences that could be broken up for easier reading, occasional repetition of ideas (e.g., “responsible AI” appears multiple times), and a lack of specific policy examples beyond the 2020 strategy. Overall, the essay demonstrates coherent, focused thinking with good flow and supporting evidence, earning a high clarity rating.\n\nScore: 8.5/10',
#  'overall_feedback': '**Summarized Feedback**\n\n**Overall Strengths**\n- **Clear structure & logical flow** – The essay opens with a strong hook, moves smoothly from India’s AI strengths to applications, challenges, and policy recommendations, and ends with a concise, unifying conclusion.  \n- **Coherence & organization** – Each paragraph tackles a distinct theme, making the argument easy to follow.  \n- **Use of data & examples** – Concrete figures (e.g.,\u202f5\u202fmillion STEM graduates) and sector‑specific illustrations (agriculture, healthcare, education, governance) add credibility.  \n- **Balanced perspective** – Opportunities and risks are both acknowledged, showing critical insight.  \n- **Academic language** – Varied sentence structures and appropriate vocabulary (“transformative era,” “human‑centered development”) demonstrate strong command of English.  \n- **Clarity of thought** – The central thesis is evident, transitions are logical, and the conclusion reinforces the main message effectively.\n\n**Key Areas for Improvement**\n1. **Language polish**\n   - Minor grammatical slips (missing/misplaced articles) and occasional repetition of phrases such as “AI‑led growth” / “responsible AI.”  \n   - Vary wording to improve stylistic flow and break up a few overly long sentences for easier reading.\n\n2. **Evidence and citation**\n   - Back broad claims with more specific data, case studies, or recent policy milestones (e.g., details from the National AI Strategy, budget allocations, pilot projects).  \n   - Include brief citations or references to strengthen authority.\n\n3. **Depth of analysis**\n   - Move beyond description to **critical evaluation** of existing initiatives (how effective is the National AI Strategy? What gaps remain?).  \n   - Offer a **comparative lens**—briefly contrast India’s approach with that of other emerging economies (e.g., Brazil, Kenya).  \n   - Provide **concrete implementation pathways**: specific policy proposals, funding mechanisms, governance models, or examples of successful multi‑stakeholder pilots.  \n   - Incorporate **scenario analysis** (best‑case vs. worst‑case outcomes) to demonstrate strategic foresight.\n\n4. **Policy specificity**\n   - Expand on recommendations (e.g., “open datasets,” “multi‑stakeholder approach”) with actionable steps: standards for data sharing, incentives for ethical AI startups, regulatory sandboxes, etc.\n\n**Combined Scores (average)**\n- Language: 8.5/10  \n- Depth of Analysis: 7/10  \n- Clarity of Thought: 8.5/10  \n\n**Overall Rating:** **≈\u202f8/10** – The essay is well‑written, well‑organized, and persuasive, but it would benefit from tighter language editing, richer evidence, deeper critical analysis, and more concrete policy detail to reach a higher academic‑policy standard.',
#  'individual_score': [7.0, 8.5, 8.5],
#  'avg_score': 8.0}
